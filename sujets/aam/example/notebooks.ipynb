# %% [markdown]
# ### Requirements or suggestions:
# - pandas
# - polars
# - fastparquet
# - matplotlib
# - pyarrow

# %%
# !pip install pandas matplotlib fastparquet matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 685.9/685.9 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.2 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# Metadata, such as ID, sector, industry, etc.
metadata = pd.read_parquet('../data/metadata.parquet', engine='fastparquet')

# Matrices of data
price = pd.read_parquet('../data/price.parquet', engine='fastparquet')
universe = pd.read_parquet('../data/universe.parquet', engine='fastparquet')
esg_score = pd.read_parquet('../data/esg_score.parquet', engine='fastparquet')
itr = pd.read_parquet('../data/itr.parquet', engine='fastparquet')

# %%
print("Metadata:")
display(metadata.head())
print("Price data:")
display(price.head())
print("Universe data:")
display(universe.head())
print("ESG Score data:")
display(esg_score.head())
print("ITR data:")
display(itr.head())
# Out:
# Metadata:
#          ID                        NAME      COUNTRY                  SECTOR  \
# 0  1COVG.DE                 COVESTRO AG      Germany               Materials
# 1    ABI.BR  ANHEUSER-BUSCH INBEV SA/NV      Belgium        Consumer Staples
# 2    ABN.AS        ABN AMRO BANK NV-CVA  Netherlands              Financials
# 3     AC.PA                    ACCOR SA       France  Consumer Discretionary
# 4    ACA.PA          CREDIT AGRICOLE SA       France              Financials
#
#              INDUSTRY_GROUP                       INDUSTRY  \
# 0                 Materials                      Chemicals
# 1  Food, Beverage & Tobacco                      Beverages
# 2                     Banks                          Banks
# 3         Consumer Services  Hotels, Restaurants & Leisure
# 4                     Banks                          Banks
#
#                      SUB_INDUSTRY PRICE_COVERAGE_START PRICE_COVERAGE_END  \
# ...

# %%
import sys
sys.path.append('..')
from tools import compute_temperature, portfolio_with_drift

# Example usage
temperature = compute_temperature(itr, pd.Timestamp('2024-06-01'), universe.iloc[5])
print("Temperature:", temperature)

portfolio_value, daily_weights = portfolio_with_drift(universe, price)
portfolio_value.plot(title='Portfolio Value with Drift')
# Out:
# Temperature: 2.251713131517132
# <Axes: title={'center': 'Portfolio Value with Drift'}, xlabel='date'>
